# %% [markdown]
# <h2>Biblioteca básica - <strong>PYTHON</strong></h2>
# <li>
#     <ul>Função Matemática.: <a href='https://docs.python.org/pt-br/3.14/library/math.html'>link da documentação</a></ul>
#     <ul>A Biblioteca Padrão do Python.: <a href='https://docs.python.org/pt-br/3.14/library/index.html'>link da documentação</a></ul>
#     <ul>Tutorial Python.: <a href='https://docs.python.org/3/tutorial/index.html'>link do tutorial da linguagem</a></ul>
#     <ul>Pacotes.: <a href='https://pypi.org/'>link de índices</a></ul>
#     <ul>Biblioteca Radom.: <a href='https://docs.python.org/pt-br/3.14/library/random.html'>link da documentação</a></ul>
#     <ul>Biblioteca python-docx.: <a href='https://python-docx.readthedocs.io/en/latest/'>link da documentação</a></ul>
#     <ul>Biblioteca pint.: <a href='https://pint.readthedocs.io/en/stable/'>link da documentação</a></ul>
#     <ul>Biblioteca Pygame.: <a href='https://www.pygame.org/docs/'>link da documentação</a></ul>
#     <ul>Biblioteca PyInstaller.: <a href='https://pyinstaller.org/en/stable/'>link da documentação</a></ul>
#     <ul>Biblioteca Emoji.: <a href='https://pypi.org/project/emoji/'>link da documentação</a></ul>
# </li>
